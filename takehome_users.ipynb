# %%
import pandas as pd
from google.colab import files
import io

# %%
uploaded_file = files.upload()
# Out:
#      <input type="file" id="files-cde7c1c7-4686-4e73-870f-e494978af702" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cde7c1c7-4686-4e73-870f-e494978af702">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving takehome_users - takehome_users.csv to takehome_users - takehome_users.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded_file['takehome_users - takehome_users.csv']))

# %%
df.head()
# Out:
#    object_id        creation_time               name  \
# 0          1   2014-04-22 3:53:30     Clausen August
# 1          2   2013-11-15 3:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4   2013-05-21 8:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
df.tail()
# Out:
#        object_id        creation_time           name  \
# 11995      11996   2013-09-06 6:14:15   Meier Sophia
# 11996      11997  2013-01-10 18:28:37  Fisher Amelie
# 11997      11998  2014-04-27 12:45:16    Haynes Jake
# 11998      11999  2012-05-31 11:55:59   Faber Annett
# 11999      12000   2014-01-26 8:57:12     Lima Thaís
#
#                            email     creation_source  \
# 11995      SophiaMeier@gustr.com          ORG_INVITE
# 11996     AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 11997        JakeHaynes@cuvox.de        GUEST_INVITE
# 11998         mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 11999  ThaisMeloLima@hotmail.com              SIGNUP
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 11995                1.378448e+09                         0
# 11996                1.358275e+09                         0
# 11997                1.398603e+09                         1
# 11998                1.338638e+09                         0
# ...

# %%
df.shape
# Out:
# (12000, 10)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.normal(size=1000)
x
# Out:
# array([ 1.27136729e+00, -2.22718629e+00,  1.53285653e+00,  4.69438810e-01,
#        -1.42244960e+00,  4.40681119e-01, -1.22199410e-01, -6.85245858e-01,
#        -3.12836690e-01,  3.35621381e-01,  2.44643768e-01,  3.01324208e-01,
#        -9.93122186e-01,  7.18540168e-01,  1.60401108e+00,  2.30146260e+00,
#        -5.30502460e-01, -1.02043870e+00,  1.66942099e+00, -1.39699302e-01,
#         1.38942137e+00, -1.23681677e+00,  1.68571112e-01, -1.23170391e+00,
#        -1.08888731e+00,  1.46071141e+00,  1.54666588e+00,  1.07759923e-01,
#         7.58478028e-02,  1.58700329e+00,  8.66210561e-02,  5.30596735e-01,
#         9.98556386e-01,  4.03416740e-01,  4.23275185e-01,  4.07139983e-01,
#         1.58714748e+00, -5.36767556e-01, -1.04677899e+00, -7.43614446e-01,
#         2.90574849e-01,  1.64092232e+00, -8.08918942e-01, -3.75783781e-01,
#         1.97138805e-01,  1.18219816e+00, -1.47206159e-01,  1.47885860e+00,
# ...

# %%
x.mean()
# Out:
# 0.03364546994698124

# %%
plt.plot(x)
plt.show()

# %%
x.min(),x.max()
# Out:
# (-3.307362193669227, 2.857768509162016)

# %%
plt.hist(x,bins=1000)
plt.show()

# %%
plt.bar(x,height=1000)
plt.show()

# %%
plt.pie(x=1000)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """Entry point for launching an IPython kernel.

# %%
import seaborn as sns

# %%
sns.distplot(x,hist=False)
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# []

# %%
sns.distplot(x,hist=True)
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# []

# %%
x=np.random.normal(loc=60,scale=5,size=1000)#x
y=np.random.normal(loc=60,scale=5,size=1000)#y
plt.hist(x,bins=20)
plt.show()
plt.plot(x)
plt.show()
sns.distplot(x,hist=False,label='normal 5')#x
sns.distplot(y,hist=False,label='normal 2')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.normal(loc=60,scale=5,size=1000)#x
y=np.random.normal(loc=60,scale=5,size=2000)#y
plt.hist(x,bins=20)
plt.show()
plt.plot(x)
plt.show()
sns.distplot(x,hist=True,label='normal 5')#x
sns.distplot(y,hist=True,label='normal 2')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dir(np.random)
# Out:
# ['BitGenerator',
#  'Generator',
#  'MT19937',
#  'PCG64',
#  'PCG64DXSM',
#  'Philox',
#  'RandomState',
#  'SFC64',
#  'SeedSequence',
#  '__RandomState_ctor',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_bounded_integers',
#  '_common',
#  '_generator',
#  '_mt19937',
#  '_pcg64',
#  '_philox',
#  '_pickle',
#  '_sfc64',
#  'beta',
#  'binomial',
#  'bit_generator',
#  'bytes',
#  'chisquare',
#  'choice',
#  'default_rng',
#  'dirichlet',
#  'exponential',
#  'f',
#  'gamma',
#  'geometric',
#  'get_state',
#  'gumbel',
#  'hypergeometric',
#  'laplace',
#  'logistic',
#  'lognormal',
#  'logseries',
#  'mtrand',
#  'multinomial',
#  'multivariate_normal',
#  'negative_binomial',
#  'noncentral_chisquare',
#  'noncentral_f',
#  'normal',
#  'pareto',
#  'permutation',
#  'poisson',
#  'power',
#  'rand',
#  'randint',
#  'randn',
#  'random',
# ...

# %%
y=np.random.binomial(n=750,p=0.6,size=100)
y
# Out:
# array([451, 446, 474, 453, 431, 453, 458, 450, 453, 465, 458, 455, 450,
#        447, 451, 456, 442, 428, 453, 441, 466, 436, 452, 454, 447, 451,
#        449, 436, 464, 450, 449, 445, 452, 468, 456, 440, 432, 439, 450,
#        459, 439, 438, 456, 435, 439, 472, 441, 448, 436, 439, 437, 455,
#        453, 446, 464, 455, 466, 429, 447, 467, 445, 449, 481, 431, 444,
#        458, 403, 436, 455, 442, 469, 470, 455, 452, 463, 450, 442, 454,
#        470, 443, 440, 448, 459, 436, 478, 437, 479, 440, 476, 440, 434,
#        441, 442, 457, 451, 468, 457, 442, 456, 443])

# %%
y=np.random.binomial(n=750,p=0.6,size=1000)
plt.hist(y,bins=20)
plt.show()
plt.plot(y)
plt.show()
sns.distplot(y,hist=False,label='bino')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
y=np.random.binomial(n=750,p=0.6,size=1000)
plt.hist(y,bins=20)
plt.show()
plt.plot(y)
plt.show()
sns.distplot(y,hist=True,label='bino')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.normal(loc=60,scale=10,size=1000)#x
y=np.random.binomial(n=100,p=0.6,size=1000)
sns.distplot(x,hist=False,label='normal')#y
sns.distplot(y,hist=False,label='bino')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.normal(loc=60,scale=10,size=1000)#x
y=np.random.binomial(n=100,p=0.6,size=1000)
sns.distplot(x,hist=True,label='normal')#y
sns.distplot(y,hist=False,label='bino')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
np.var(x)
# Out:
# 94.32482502999619

# %%
np.sqrt(np.mean((x-np.mean(x))**2))#standard dev
# Out:
# 9.71209684002359

# %%
np.mean((x-np.mean(x))**2)#variance
# Out:
# 94.32482502999619

# %%
z=np.random.poisson(lam=60,size=1000)
plt.hist(z,bins=20)
plt.show()
plt.plot(z)
plt.show()
sns.distplot(z,hist=False,label='bino')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.normal(loc=60,scale=5,size=1000)#x
y=np.random.binomial(n=100,p=0.6,size=1000)
z=np.random.poisson(lam=60,size=1000)
sns.distplot(x,hist=False,label='normal')#y
sns.distplot(y,hist=False,label='bino')#y
sns.distplot(z,hist=False,label='poisson')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
i=np.random.uniform(low=55,high=65,size=1000)
plt.hist(i,bins=20)
plt.show()
plt.plot(i)
plt.show()
sns.distplot(i,hist=False,label='uniform')#y
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.normal(loc=60,scale=5,size=1000)#x
y=np.random.binomial(n=100,p=0.6,size=1000)
z=np.random.poisson(lam=60,size=1000)
i=np.random.uniform(low=45,high=75,size=1000)
sns.distplot(x,hist=False,label='normal')#y
sns.distplot(y,hist=False,label='bino')#y
sns.distplot(z,hist=False,label='poisson')
sns.distplot(i,hist=False,label='uniform')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...
